# %%
import pandas as pd
df = pd.read_csv('amazon_data-3.csv')

# %%
df.head(20)
# Out:
#                               Product_ID  \
# 0   065fbe37-c7d5-4a49-a104-be663cc0d662
# 1   7edaf615-2474-40db-87d2-01ca4538256b
# 2   48048dcd-3bf6-454a-a6a6-50acd5f8538a
# 3   9b37bb66-4551-469a-99ef-565f889f095a
# 4   45d073fb-ab85-42d9-91b8-c1e7c062e273
# 5   acb6db46-b613-4968-8d32-0b61f76af2b2
# 6   ee68874a-507c-470e-83dc-1d36f3fc4cf3
# 7   be2987ae-f6f5-4718-86c0-518e1662f6f4
# 8   0816ba4e-926b-47d1-966a-2e548a0988ca
# 9   e80156e2-98a8-4411-acd6-e3df7e77673f
# 10  eedaa33b-04cc-49e1-b80e-fca91846064a
# 11  47e35eb9-d803-4e47-ae36-9a892f21829a
# 12  334e3db7-cd42-4451-b981-b8b6c43b9a88
# 13  ec1e5ea1-b3a0-4934-ba3b-deb5737f1b3b
# 14  a487c759-1b5d-4116-9e98-41cfebb9f96e
# 15  4b633fb6-c015-4806-81c1-aef913ee1828
# 16  076d19a1-acad-46c2-aef5-8aec408ac6c9
# 17  710d2fe3-c3a8-4200-bc6d-92ff65e31c6f
# 18  b935f87d-887a-4111-ae8d-f7add453af2b
# 19  ce047175-593d-4bcb-a82f-4c5536216e4a
#
#                                               product   price  ratings  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['url']
# Out:
# 0      https://www.amazon.com/Xiaomi-Unlocked-Warrant...
# 1      https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 2      https://www.amazon.com/Samsung-Galaxy-S9-Unloc...
# 3      https://www.amazon.com/SAMSUNG-Factory-Unlocke...
# 4      https://www.amazon.com/sspa/click?ie=UTF8&spc=...
#                              ...
# 360    https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 361    https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 362    https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 363    https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 364    https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# Name: url, Length: 365, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product_ID  365 non-null    object
#  1   product     365 non-null    object
#  2   price       365 non-null    float64
#  3   ratings     365 non-null    float64
#  4   reviews     365 non-null    int64
#  5   url         365 non-null    object
#  6   category    365 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 20.1+ KB
